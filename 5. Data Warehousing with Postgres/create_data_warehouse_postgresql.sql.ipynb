# %% [markdown]
# # Data Warehousing with PostgreSQL
#
# ## Load modules

# %%
# create data warehouse with postgres

# load packages
# !pip install ipython-sql
# !pip install sqlalchemy
# !pip install psycopg2

#import the creat_engine module from sqlalchemy
from sqlalchemy import create_engine
import pandas as pd 
import matplotlib.pyplot as plt 
import psycopg2
# use the following magic command to load the ipython-sql
# %load_ext sql

# %% [markdown]
# ## Connect to my Postgres server

# %%
# place the db connection inside a try except block
conn = None
cur = None

try:
    conn = psycopg2.connect( 
        host = 'localhost', 
        dbname = 'wasteDB', 
        user='postgres',
        password='PASSWORD', 
        port=5434)
    
    # create a cursor object 
    cur = conn.cursor()
    
    #create the tables for the database 
    create_script = '''

        CREATE TABLE IF NOT EXISTS public."FactTrips"
        (
            "Tripid" integer NOT NULL,
            "Dateid" integer,
            "Stationid" integer,
            "Truckid" integer,
            "Wastecollected" numeric,
            PRIMARY KEY ("Tripid")
        );

        CREATE TABLE IF NOT EXISTS public."DimTruck"
        (
            "Truckid" integer NOT NULL,
            "TruckType" character varying(10),
            PRIMARY KEY ("Truckid")
        );

        CREATE TABLE IF NOT EXISTS public."DimDate"
        (
            "Dateid" integer NOT NULL,
            "Date" timestamp without time zone,
            "Year" integer,
            "Quarter" integer,
            "QuarterName" character varying(3),
            month integer,
            "MonthName" character varying(10),
            "Day" integer,
            "WeekDay" integer,
            "WeekDayName" character varying(10),
            PRIMARY KEY ("Dateid")
        );

        CREATE TABLE IF NOT EXISTS public."DimStation"
        (
            "Stationid" integer NOT NULL,
            "City" character varying(30),
            PRIMARY KEY ("Stationid")
        );

        ALTER TABLE IF EXISTS public."FactTrips"
            ADD FOREIGN KEY ("Dateid")
            REFERENCES public."DimDate" ("Dateid") MATCH SIMPLE
            ON UPDATE NO ACTION
            ON DELETE NO ACTION
            NOT VALID;


        ALTER TABLE IF EXISTS public."FactTrips"
            ADD FOREIGN KEY ("Stationid")
            REFERENCES public."DimStation" ("Stationid") MATCH SIMPLE
            ON UPDATE NO ACTION
            ON DELETE NO ACTION
            NOT VALID;


        ALTER TABLE IF EXISTS public."FactTrips"
            ADD FOREIGN KEY ("Truckid")
            REFERENCES public."DimTruck" ("Truckid") MATCH SIMPLE
            ON UPDATE NO ACTION
            ON DELETE NO ACTION
            NOT VALID;

'''
    
    cur.execute(create_script)
    
    conn.commit()

except Exception as error:
    print(error)
    
finally: 
    if cur is not None:
        cur.close()
    if conn is not None:
        conn.close()
# Out:
# relation "MyDimDate" already exists

# %%
#Connect to the wasteDB 
# %sql postgresql://postgres:PASSWORD@localhost:5434/wasteDB

# %%
#query the tables in the databases
#query the first 10 rows in the FactTrips
# %sql SELECT * FROM public."FactTrips" LIMIT 10;
# Out:
#  * postgresql://postgres:***@localhost:5434/wasteDB
# 10 rows affected.
# [(23475, 1, 71, 133, Decimal('33.36')),
#  (23476, 1, 46, 162, Decimal('34.88')),
#  (23477, 1, 40, 134, Decimal('34.69')),
#  (23478, 1, 43, 148, Decimal('30.01')),
#  (23479, 1, 46, 169, Decimal('37.47')),
#  (23480, 1, 71, 126, Decimal('40.33')),
#  (23481, 1, 46, 161, Decimal('41.92')),
#  (23482, 1, 97, 120, Decimal('30.6')),
#  (23483, 1, 40, 137, Decimal('43.56')),
#  (23484, 1, 97, 120, Decimal('31.87'))]

# %%
#query the first 10 rows in the DimTruck table
# %%sql 
SELECT * FROM public."DimTruck"
LIMIT 10;
# Out:
#  * postgresql://postgres:***@localhost:5434/wasteDB
# 10 rows affected.
# [(115, 'Volvo'),
#  (120, 'Scania'),
#  (121, 'Volvo'),
#  (122, 'Scania'),
#  (125, 'Volvo'),
#  (126, 'Scania'),
#  (130, 'Scania'),
#  (133, 'Volvo'),
#  (134, 'Scania'),
#  (135, 'Volvo')]

# %%
#query the first 10 rows in the DimStation table
# %%sql 
SELECT * FROM public."DimStation"
LIMIT 10;
# Out:
#    postgresql://adriancortes:***@localhost/postgres
#  * postgresql://postgres:***@localhost:5434/wasteDB
# 10 rows affected.
# [(19, 'Sao Paulo'),
#  (21, 'Sao Paulo'),
#  (31, 'Rio de Janeiro'),
#  (32, 'Rio de Janeiro'),
#  (40, 'Brasilia'),
#  (43, 'Brasilia'),
#  (44, 'Rio de Janeiro'),
#  (46, 'Brasilia'),
#  (47, 'Salvador'),
#  (48, 'Salvador')]

# %%
#query the first 10 rows in the DimDate table 
# %%sql 
SELECT * FROM public."DimDate"
LIMIT 10;
# Out:
#  * postgresql://postgres:***@localhost:5434/wasteDB
# 10 rows affected.
# [(1, datetime.datetime(2019, 3, 9, 0, 0), 2019, 1, 'Q1', 3, 'March', 9, 7, 'Sunday'),
#  (2, datetime.datetime(2019, 3, 10, 0, 0), 2019, 1, 'Q1', 3, 'March', 10, 1, 'Monday'),
#  (3, datetime.datetime(2019, 3, 11, 0, 0), 2019, 1, 'Q1', 3, 'March', 11, 2, 'Tuesday'),
#  (4, datetime.datetime(2019, 3, 12, 0, 0), 2019, 1, 'Q1', 3, 'March', 12, 3, 'Wednesday'),
#  (5, datetime.datetime(2019, 3, 13, 0, 0), 2019, 1, 'Q1', 3, 'March', 13, 4, 'Thursday'),
#  (6, datetime.datetime(2019, 3, 14, 0, 0), 2019, 1, 'Q1', 3, 'March', 14, 5, 'Friday'),
#  (7, datetime.datetime(2019, 3, 15, 0, 0), 2019, 1, 'Q1', 3, 'March', 15, 6, 'Saturday'),
#  (8, datetime.datetime(2019, 3, 16, 0, 0), 2019, 1, 'Q1', 3, 'March', 16, 7, 'Sunday'),
#  (9, datetime.datetime(2019, 3, 17, 0, 0), 2019, 1, 'Q1', 3, 'March', 17, 1, 'Monday'),
#  (10, datetime.datetime(2019, 3, 18, 0, 0), 2019, 1, 'Q1', 3, 'March', 18, 2, 'Tuesday')]

# %% [markdown]
# ## Create Aggregation Queries and MQTs
#
# Write aggregation queries using **CUBE** and **ROLLUP** functions and create materialized query tables (materialized view)

# %% [markdown]
# 1. Create a grouping sets query using the columns stationid, trucktype, total waste collected

# %%
# %%sql
# SELECT "FactTrips"."Stationid",
# "DimTruck"."TruckType",
# SUM("FactTrips"."WasteCollected")
# FROM public."FactTrips"
# --left join the DimTruck table on the truckid column
# LEFT JOIN public."DimTruck"
# ON "FactTrips"."Truckid" = "DimTruck"."Truckid"
# GROUP BY
# GROUPING SETS(
# "Stationid",
# "TruckType"
# )
# ORDER BY
# "TruckType",
# "Stationid";
# Out:
#  * postgresql://postgres:***@localhost:5434/wasteDB
# 21 rows affected.
# [(None, 'Scania', Decimal('2079167.04')),
#  (None, 'Volvo', Decimal('1908758.30')),
#  (19, None, Decimal('332816.78')),
#  (21, None, Decimal('333142.01')),
#  (31, None, Decimal('167061.68')),
#  (32, None, Decimal('167764.84')),
#  (40, None, Decimal('163671.71')),
#  (43, None, Decimal('166730.64')),
#  (44, None, Decimal('166456.22')),
#  (46, None, Decimal('169264.68')),
#  (47, None, Decimal('248569.92')),
#  (48, None, Decimal('254136.86')),
#  (57, None, Decimal('164839.47')),
#  (71, None, Decimal('165131.77')),
#  (77, None, Decimal('165914.25')),
#  (81, None, Decimal('247492.72')),
#  (82, None, Decimal('246759.30')),
#  (83, None, Decimal('332035.37')),
#  (84, None, Decimal('166212.16')),
#  (86, None, Decimal('163940.76')),
#  (97, None, Decimal('165984.20'))]

# %% [markdown]
# 2. Create a rollup query using the columns year, city, stationid, and total waste collected

# %%
# %%sql
# SELECT "DimDate"."Year",
# "DimStation"."City",
# "FactTrips"."Stationid",
# SUM("FactTrips"."WasteCollected")
# FROM public."FactTrips"
# LEFT JOIN public."DimDate"
# ON "FactTrips"."Dateid" = "DimDate"."Dateid"
# LEFT JOIN public."DimStation"
# ON "FactTrips"."Stationid" = "DimStation"."Stationid"
# GROUP BY
# ROLLUP(
# "DimDate"."Year",
# "DimStation"."City",
# "FactTrips"."Stationid"
# )
# ORDER BY
# "DimDate"."Year",
# "DimStation"."City",
# "FactTrips"."Stationid";
# Out:
#  * postgresql://postgres:***@localhost:5434/wasteDB
# 49 rows affected.
# [(2019, 'Brasilia', 40, Decimal('138850.54')),
#  (2019, 'Brasilia', 43, Decimal('141503.54')),
#  (2019, 'Brasilia', 46, Decimal('144418.78')),
#  (2019, 'Brasilia', 71, Decimal('141856.38')),
#  (2019, 'Brasilia', 77, Decimal('141627.10')),
#  (2019, 'Brasilia', 97, Decimal('140485.97')),
#  (2019, 'Brasilia', None, Decimal('848742.31')),
#  (2019, 'Rio de Janeiro', 31, Decimal('143821.05')),
#  (2019, 'Rio de Janeiro', 32, Decimal('142766.60')),
#  (2019, 'Rio de Janeiro', 44, Decimal('141766.33')),
#  (2019, 'Rio de Janeiro', 57, Decimal('141405.86')),
#  (2019, 'Rio de Janeiro', 84, Decimal('139342.97')),
#  (2019, 'Rio de Janeiro', 86, Decimal('139200.81')),
#  (2019, 'Rio de Janeiro', None, Decimal('848303.62')),
#  (2019, 'Salvador', 47, Decimal('210905.85')),
#  (2019, 'Salvador', 48, Decimal('217131.48')),
#  (2019, 'Salvador', 81, Decimal('211896.03')),
#  (2019, 'Salvador', 82, Decimal('209026.86')),
#  (2019, 'Salvador', None, Decimal('848960.22')),
#  (2019, 'Sao Paulo', 19, Decimal('284166.96')),
#  (2019, 'Sao Paulo', 21, Decimal('283182.30')),
#  (2019, 'Sao Paulo', 83, Decimal('282277.08')),
#  (2019, 'Sao Paulo', None, Decimal('849626.34')),
#  (2019, None, None, Decimal('3395632.49')),
#  (2020, 'Brasilia', 40, Decimal('24821.17')),
#  (2020, 'Brasilia', 43, Decimal('25227.10')),
#  (2020, 'Brasilia', 46, Decimal('24845.90')),
#  (2020, 'Brasilia', 71, Decimal('23275.39')),
#  (2020, 'Brasilia', 77, Decimal('24287.15')),
#  (2020, 'Brasilia', 97, Decimal('25498.23')),
#  (2020, 'Brasilia', None, Decimal('147954.94')),
#  (2020, 'Rio de Janeiro', 31, Decimal('23240.63')),
#  (2020, 'Rio de Janeiro', 32, Decimal('24998.24')),
#  (2020, 'Rio de Janeiro', 44, Decimal('24689.89')),
#  (2020, 'Rio de Janeiro', 57, Decimal('23433.61')),
#  (2020, 'Rio de Janeiro', 84, Decimal('26869.19')),
#  (2020, 'Rio de Janeiro', 86, Decimal('24739.95')),
#  (2020, 'Rio de Janeiro', None, Decimal('147971.51')),
#  (2020, 'Salvador', 47, Decimal('37664.07')),
#  (2020, 'Salvador', 48, Decimal('37005.38')),
#  (2020, 'Salvador', 81, Decimal('35596.69')),
#  (2020, 'Salvador', 82, Decimal('37732.44')),
#  (2020, 'Salvador', None, Decimal('147998.58')),
#  (2020, 'Sao Paulo', 19, Decimal('48649.82')),
#  (2020, 'Sao Paulo', 21, Decimal('49959.71')),
#  (2020, 'Sao Paulo', 83, Decimal('49758.29')),
#  (2020, 'Sao Paulo', None, Decimal('148367.82')),
#  (2020, None, None, Decimal('592292.85')),
#  (None, None, None, Decimal('3987925.34'))]

# %% [markdown]
# 3. Create a cube query using the columns year, city, stationid, and average waste collected

# %%
# %%sql
# SELECT "DimDate"."Year",
# "DimStation"."City",
# "FactTrips"."Stationid",
# AVG("FactTrips"."WasteCollected")
# FROM public."FactTrips"
# LEFT JOIN public."DimDate"
# ON "FactTrips"."Dateid" = "DimDate"."Dateid"
# LEFT JOIN public."DimStation"
# ON "FactTrips"."Stationid" = "DimStation"."Stationid"
# GROUP BY
# CUBE(
# "DimDate"."Year",
# "DimStation"."City",
# "FactTrips"."Stationid"
# )
# ORDER BY
# "DimDate"."Year",
# "DimStation"."City",
# "FactTrips"."Stationid";
# Out:
#  * postgresql://postgres:***@localhost:5434/wasteDB
# 129 rows affected.
# [(2019, 'Brasilia', 40, Decimal('37.3756500672947510')),
#  (2019, 'Brasilia', 43, Decimal('37.5042512589451365')),
#  (2019, 'Brasilia', 46, Decimal('37.5016307452609712')),
#  (2019, 'Brasilia', 71, Decimal('37.4587747557433325')),
#  (2019, 'Brasilia', 77, Decimal('37.4674867724867725')),
#  (2019, 'Brasilia', 97, Decimal('37.5430171031533939')),
#  (2019, 'Brasilia', None, Decimal('37.4753757506181561')),
#  (2019, 'Rio de Janeiro', 31, Decimal('37.4631544673091951')),
#  (2019, 'Rio de Janeiro', 32, Decimal('37.5207884362680683')),
#  (2019, 'Rio de Janeiro', 44, Decimal('37.4547767503302510')),
#  (2019, 'Rio de Janeiro', 57, Decimal('37.4188568404339772')),
#  (2019, 'Rio de Janeiro', 84, Decimal('37.4779370629370629')),
#  (2019, 'Rio de Janeiro', 86, Decimal('37.3994653412144009')),
#  (2019, 'Rio de Janeiro', None, Decimal('37.4560058283292123')),
#  (2019, 'Salvador', 47, Decimal('37.5277313167259786')),
#  (2019, 'Salvador', 48, Decimal('37.4752295478080773')),
#  (2019, 'Salvador', 81, Decimal('37.4242370187212999')),
#  (2019, 'Salvador', 82, Decimal('37.5137939698492462')),
#  (2019, 'Salvador', None, Decimal('37.4849973507594490')),
#  (2019, 'Sao Paulo', 19, Decimal('37.5683447911158117')),
#  (2019, 'Sao Paulo', 21, Decimal('37.4431178103927013')),
#  (2019, 'Sao Paulo', 83, Decimal('37.5318548065416833')),
#  (2019, 'Sao Paulo', None, Decimal('37.5144092193571176')),
#  (2019, None, 19, Decimal('37.5683447911158117')),
#  (2019, None, 21, Decimal('37.4431178103927013')),
#  (2019, None, 31, Decimal('37.4631544673091951')),
#  (2019, None, 32, Decimal('37.5207884362680683')),
#  (2019, None, 40, Decimal('37.3756500672947510')),
#  (2019, None, 43, Decimal('37.5042512589451365')),
#  (2019, None, 44, Decimal('37.4547767503302510')),
#  (2019, None, 46, Decimal('37.5016307452609712')),
#  (2019, None, 47, Decimal('37.5277313167259786')),
#  (2019, None, 48, Decimal('37.4752295478080773')),
#  (2019, None, 57, Decimal('37.4188568404339772')),
#  (2019, None, 71, Decimal('37.4587747557433325')),
#  (2019, None, 77, Decimal('37.4674867724867725')),
#  (2019, None, 81, Decimal('37.4242370187212999')),
#  (2019, None, 82, Decimal('37.5137939698492462')),
#  (2019, None, 83, Decimal('37.5318548065416833')),
#  (2019, None, 84, Decimal('37.4779370629370629')),
#  (2019, None, 86, Decimal('37.3994653412144009')),
#  (2019, None, 97, Decimal('37.5430171031533939')),
#  (2019, None, None, Decimal('37.4826970372659838')),
#  (2020, 'Brasilia', 40, Decimal('37.4942145015105740')),
#  (2020, 'Brasilia', 43, Decimal('37.2081120943952802')),
#  (2020, 'Brasilia', 46, Decimal('37.4185240963855422')),
#  (2020, 'Brasilia', 71, Decimal('37.4804991948470209')),
#  (2020, 'Brasilia', 77, Decimal('37.3648461538461538')),
#  (2020, 'Brasilia', 97, Decimal('37.6635598227474151')),
#  (2020, 'Brasilia', None, Decimal('37.4379908906882591')),
#  (2020, 'Rio de Janeiro', 31, Decimal('37.1850080000000000')),
#  (2020, 'Rio de Janeiro', 32, Decimal('37.4786206896551724')),
#  (2020, 'Rio de Janeiro', 44, Decimal('37.2959063444108761')),
#  (2020, 'Rio de Janeiro', 57, Decimal('37.4937760000000000')),
#  (2020, 'Rio de Janeiro', 84, Decimal('37.5268016759776536')),
#  (2020, 'Rio de Janeiro', 86, Decimal('37.6559360730593607')),
#  (2020, 'Rio de Janeiro', None, Decimal('37.4421837044534413')),
#  (2020, 'Salvador', 47, Decimal('37.2911584158415842')),
#  (2020, 'Salvador', 48, Decimal('37.4927862208713273')),
#  (2020, 'Salvador', 81, Decimal('37.7483457051961824')),
#  (2020, 'Salvador', 82, Decimal('37.2850197628458498')),
#  (2020, 'Salvador', None, Decimal('37.4490334008097166')),
#  (2020, 'Sao Paulo', 19, Decimal('37.7130387596899225')),
#  (2020, 'Sao Paulo', 21, Decimal('37.5354695717505635')),
#  (2020, 'Sao Paulo', 83, Decimal('37.3841397445529677')),
#  (2020, 'Sao Paulo', None, Decimal('37.5424645748987854')),
#  (2020, None, 19, Decimal('37.7130387596899225')),
#  (2020, None, 21, Decimal('37.5354695717505635')),
#  (2020, None, 31, Decimal('37.1850080000000000')),
#  (2020, None, 32, Decimal('37.4786206896551724')),
#  (2020, None, 40, Decimal('37.4942145015105740')),
#  (2020, None, 43, Decimal('37.2081120943952802')),
#  (2020, None, 44, Decimal('37.2959063444108761')),
#  (2020, None, 46, Decimal('37.4185240963855422')),
#  (2020, None, 47, Decimal('37.2911584158415842')),
#  (2020, None, 48, Decimal('37.4927862208713273')),
#  (2020, None, 57, Decimal('37.4937760000000000')),
#  (2020, None, 71, Decimal('37.4804991948470209')),
#  (2020, None, 77, Decimal('37.3648461538461538')),
#  (2020, None, 81, Decimal('37.7483457051961824')),
#  (2020, None, 82, Decimal('37.2850197628458498')),
#  (2020, None, 83, Decimal('37.3841397445529677')),
#  (2020, None, 84, Decimal('37.5268016759776536')),
#  (2020, None, 86, Decimal('37.6559360730593607')),
#  (2020, None, 97, Decimal('37.6635598227474151')),
#  (2020, None, None, Decimal('37.4679181427125506')),
#  (None, 'Brasilia', 40, Decimal('37.3935823623486406')),
#  (None, 'Brasilia', 43, Decimal('37.4591417658953044')),
#  (None, 'Brasilia', 46, Decimal('37.4894086378737542')),
#  (None, 'Brasilia', 71, Decimal('37.4618352994555354')),
#  (None, 'Brasilia', 77, Decimal('37.4524266365688488')),
#  (None, 'Brasilia', 97, Decimal('37.5614844987553745')),
#  (None, 'Brasilia', None, Decimal('37.4698214285714286')),
#  (None, 'Rio de Janeiro', 31, Decimal('37.4242114695340502')),
#  (None, 'Rio de Janeiro', 32, Decimal('37.5144991055456172')),
#  (None, 'Rio de Janeiro', 44, Decimal('37.4311266022037329')),
#  (None, 'Rio de Janeiro', 57, Decimal('37.4294891008174387')),
#  (None, 'Rio de Janeiro', 84, Decimal('37.4858276950834461')),
#  (None, 'Rio de Janeiro', 86, Decimal('37.4379447362411509')),
#  (None, 'Rio de Janeiro', None, Decimal('37.4539522556390977')),
#  (None, 'Salvador', 47, Decimal('37.4916923076923077')),
#  (None, 'Salvador', 48, Decimal('37.4777849874649757')),
#  (None, 'Salvador', 81, Decimal('37.4705102195306586')),
#  (None, 'Salvador', 82, Decimal('37.4786300121506683')),
#  (None, 'Salvador', None, Decimal('37.4796541353383459')),
#  (None, 'Sao Paulo', 19, Decimal('37.5894262480234922')),
#  (None, 'Sao Paulo', 21, Decimal('37.4569383854283787')),
#  (None, 'Sao Paulo', 83, Decimal('37.5096441482150926')),
#  (None, 'Sao Paulo', None, Decimal('37.5185774436090226')),
#  (None, None, 19, Decimal('37.5894262480234922')),
#  (None, None, 21, Decimal('37.4569383854283787')),
#  (None, None, 31, Decimal('37.4242114695340502')),
#  (None, None, 32, Decimal('37.5144991055456172')),
#  (None, None, 40, Decimal('37.3935823623486406')),
#  (None, None, 43, Decimal('37.4591417658953044')),
#  (None, None, 44, Decimal('37.4311266022037329')),
#  (None, None, 46, Decimal('37.4894086378737542')),
#  (None, None, 47, Decimal('37.4916923076923077')),
#  (None, None, 48, Decimal('37.4777849874649757')),
#  (None, None, 57, Decimal('37.4294891008174387')),
#  (None, None, 71, Decimal('37.4618352994555354')),
#  (None, None, 77, Decimal('37.4524266365688488')),
#  (None, None, 81, Decimal('37.4705102195306586')),
#  (None, None, 82, Decimal('37.4786300121506683')),
#  (None, None, 83, Decimal('37.5096441482150926')),
#  (None, None, 84, Decimal('37.4858276950834461')),
#  (None, None, 86, Decimal('37.4379447362411509')),
#  (None, None, 97, Decimal('37.5614844987553745')),
#  (None, None, None, Decimal('37.4805013157894737'))]

# %% [markdown]
# 4. Create an MQT named maxwastestats using the columns city, stationid, trucktype, and max waste collected

# %%
# %%sql
# CREATE MATERIALIZED VIEW MaxWasteStats ("City", "Stationid", "TruckType", "MaxWasteCollected")
# AS (
# SELECT "DimStation"."City",
# "FactTrips"."Stationid",
# "DimTruck"."TruckType",
# MAX("FactTrips"."WasteCollected")
# FROM public."FactTrips"
# LEFT JOIN public."DimDate"
# ON "FactTrips"."Dateid" = "DimDate"."Dateid"
# LEFT JOIN public."DimStation"
# ON "FactTrips"."Stationid" = "DimStation"."Stationid"
# LEFT JOIN public."DimTruck"
# ON "FactTrips"."Truckid" = "DimTruck"."Truckid"
# GROUP BY
# "City",
# "FactTrips"."Stationid",
# "TruckType"
# ORDER BY
# "City",
# "FactTrips"."Stationid",
# "TruckType"
# );

# %%
#query the materialized view 
# %%sql
SELECT * FROM public.maxwastestats
LIMIT 100;
# Out:
#  * postgresql://postgres:***@localhost:5434/wasteDB
# 36 rows affected.
# [('Brasilia', 40, 'Scania', Decimal('45.0')),
#  ('Brasilia', 40, 'Volvo', Decimal('45.0')),
#  ('Brasilia', 43, 'Scania', Decimal('45.0')),
#  ('Brasilia', 43, 'Volvo', Decimal('44.99')),
#  ('Brasilia', 46, 'Scania', Decimal('45.0')),
#  ('Brasilia', 46, 'Volvo', Decimal('45.0')),
#  ('Brasilia', 71, 'Scania', Decimal('45.0')),
#  ('Brasilia', 71, 'Volvo', Decimal('45.0')),
#  ('Brasilia', 77, 'Scania', Decimal('45.0')),
#  ('Brasilia', 77, 'Volvo', Decimal('44.98')),
#  ('Brasilia', 97, 'Scania', Decimal('45.0')),
#  ('Brasilia', 97, 'Volvo', Decimal('45.0')),
#  ('Rio de Janeiro', 31, 'Scania', Decimal('45.0')),
#  ('Rio de Janeiro', 31, 'Volvo', Decimal('45.0')),
#  ('Rio de Janeiro', 32, 'Scania', Decimal('45.0')),
#  ('Rio de Janeiro', 32, 'Volvo', Decimal('44.99')),
#  ('Rio de Janeiro', 44, 'Scania', Decimal('45.0')),
#  ('Rio de Janeiro', 44, 'Volvo', Decimal('44.99')),
#  ('Rio de Janeiro', 57, 'Scania', Decimal('45.0')),
#  ('Rio de Janeiro', 57, 'Volvo', Decimal('44.97')),
#  ('Rio de Janeiro', 84, 'Scania', Decimal('45.0')),
#  ('Rio de Janeiro', 84, 'Volvo', Decimal('45.0')),
#  ('Rio de Janeiro', 86, 'Scania', Decimal('45.0')),
#  ('Rio de Janeiro', 86, 'Volvo', Decimal('45.0')),
#  ('Salvador', 47, 'Scania', Decimal('45.0')),
#  ('Salvador', 47, 'Volvo', Decimal('44.99')),
#  ('Salvador', 48, 'Scania', Decimal('45.0')),
#  ('Salvador', 48, 'Volvo', Decimal('45.0')),
#  ('Salvador', 81, 'Scania', Decimal('45.0')),
#  ('Salvador', 81, 'Volvo', Decimal('45.0')),
#  ('Salvador', 82, 'Volvo', Decimal('45.0')),
#  ('Sao Paulo', 19, 'Scania', Decimal('45.0')),
#  ('Sao Paulo', 19, 'Volvo', Decimal('45.0')),
#  ('Sao Paulo', 21, 'Scania', Decimal('45.0')),
#  ('Sao Paulo', 21, 'Volvo', Decimal('45.0')),
#  ('Sao Paulo', 83, 'Volvo', Decimal('45.0'))]
